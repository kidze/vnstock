# %%
from vnstock import *
import pandas as pd
data = financial_report(symbol='NVL', report_type="IncomeStatement", frequency="Yearly")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 3
#       1 from vnstock import *
#       2 import pandas as pd
# ----> 3 data = financial_report(symbol='NVL', report_type="IncomeStatement", frequency="Yearly")
#
# File /opt/homebrew/lib/python3.11/site-packages/vnstock/stock.py:172, in financial_report(symbol, report_type, frequency, headers)
#     170 url = 'https://fiin-fundamental.ssi.com.vn/FinancialStatement/Download{}?language=vi&OrganCode={}&Skip=0&Frequency={}'.format(report_type, symbol, frequency)
#     171 r = requests.get(url, headers=headers)
# --> 172 df = pd.read_excel(BytesIO(r.content), skiprows=7).dropna()
#     173 return df
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/io/excel/_base.py:364, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     362 if not isinstance(io, ExcelFile):
#     363     should_close = True
# --> 364     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     365 elif engine and engine != io.engine:
#     366     raise ValueError(
#     367         "Engine should not be specified when passing "
#     368         "an ExcelFile - ExcelFile already has the engine set"
#     369     )
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/io/excel/_base.py:1195, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1191     ext = inspect_excel_format(
#    1192         content_or_path=path_or_buffer, storage_options=storage_options
#    1193     )
#    1194     if ext is None:
# -> 1195         raise ValueError(
#    1196             "Excel file format cannot be determined, you must specify "
#    1197             "an engine manually."
#    1198         )
#    1200 engine = config.get_option(f"io.excel.{ext}.reader", silent=True)
#    1201 if engine == "auto":
#
# ValueError: Excel file format cannot be determined, you must specify an engine manually.

# %%
from vnstock import *
import pandas as pd
df = financial_ratio('SCS', 'yearly', True)
df
# Out:
#   ticker  quarter  year  priceToEarning  priceToBook  valueBeforeEbitda  \
# 0    SCS        5  2022            10.4          4.7                9.0
# 1    SCS        5  2021            13.1          5.9               14.1
# 2    SCS        5  2020            13.3          6.1               12.2
# 3    SCS        5  2019            10.9          5.5                9.0
#
#   dividend    roe    roa  daysReceivable  ...  loanOnAsset  loanOnDeposit  \
# 0     None  0.482  0.435             337  ...         None           None
# 1     None  0.498  0.449             238  ...         None           None
# 2     None  0.460  0.429             200  ...         None           None
# 3     None  0.532  0.491              32  ...         None           None
#
#    depositOnEarnAsset  badDebtOnAsset  liquidityOnLiability payableOnEquity  \
# 0                None            None                  None             0.1
# 1                None            None                  None             0.1
# 2                None            None                  None             0.1
# 3                None            None                  None             0.1
#
#   cancelDebt ebitdaOnStockChange bookValuePerShareChange creditGrowth
# 0       None              -0.205                   0.148         None
# 1       None               0.188                   0.223         None
# 2       None              -0.101                  -0.453         None
# 3       None               0.123                   0.135         None
#
# [4 rows x 59 columns]

# %%
import sys

sys.path
sys.executable
sys.path.insert(0,r"c:\python310\lib\site-packages")

# %%
from vnstock import *
import pandas as pd
df = financial_ratio('FPT', 'yearly', False)
print(df.columns)
# Out:
# Index(['ticker', 'quarter', 'year', 'priceToEarning', 'priceToBook',
#        'valueBeforeEbitda', 'dividend', 'roe', 'roa', 'daysReceivable',
#        'daysInventory', 'daysPayable', 'ebitOnInterest', 'earningPerShare',
#        'bookValuePerShare', 'interestMargin', 'nonInterestOnToi',
#        'badDebtPercentage', 'provisionOnBadDebt', 'costOfFinancing',
#        'equityOnTotalAsset', 'equityOnLoan', 'costToIncome',
#        'equityOnLiability', 'currentPayment', 'quickPayment', 'epsChange',
#        'ebitdaOnStock', 'grossProfitMargin', 'operatingProfitMargin',
#        'postTaxMargin', 'debtOnEquity', 'debtOnAsset', 'debtOnEbitda',
#        'shortOnLongDebt', 'assetOnEquity', 'capitalBalance', 'cashOnEquity',
#        'cashOnCapitalize', 'cashCirculation', 'revenueOnWorkCapital',
#        'capexOnFixedAsset', 'revenueOnAsset', 'postTaxOnPreTax',
#        'ebitOnRevenue', 'preTaxOnEbit', 'preProvisionOnToi', 'postTaxOnToi',
#        'loanOnEarnAsset', 'loanOnAsset', 'loanOnDeposit', 'depositOnEarnAsset',
#        'badDebtOnAsset', 'liquidityOnLiability', 'payableOnEquity',
#        'cancelDebt', 'ebitdaOnStockChange', 'bookValuePerShareChange',
#        'creditGrowth'],
#       dtype='object')

# %%
import pandas as pd
import json
import openpyxl
from openpyxl import load_workbook

# Read financial_data from the JSON file
with open("financial_data.json", "r") as file:
    financial_data = json.load(file)

# Assuming financial_data is a list of dictionaries
df = pd.DataFrame(financial_data)

# Load the existing workbook
book = openpyxl.load_workbook('stock-valuation-2023.xlsx')
# Create an Excel writer object with the loaded workbook
writer = pd.ExcelWriter('stock-valuation-2023.xlsx', engine='openpyxl', if_sheet_exists='replace') 
writer.workbook = book

# Delete the 'financial_data' sheet if it exists
if 'financial_data' in book.sheetnames:
    std = book['financial_data']
    book.remove(std)

# Write the DataFrame to the 'financial_data' sheet
df.to_excel(writer, sheet_name='financial_data', index=False)

# Save the workbook
writer.save()
